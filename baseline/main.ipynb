# %% [markdown]
# ## [Dacon] 블럭 장난감 제조 공정 최적화 경진대회
# ## _____ (팀명)
# ## 2020년 월 일 (제출날짜)
#
# 1. 본 코드는 대회 참가를 돕고자 단순 예시를 작성한 것으로 참고용으로 사용바랍니다.
# 2. 본 코드는 자유롭게 수정하여 사용 할 수 있습니다.
# 3. 추가 모듈 보러가기: https://bit.ly/36MNs76

# %% [markdown]
# ## 1. 라이브러리 및 데이터
# ## Library & Data

# %%
import pandas as pd
import numpy as np
import multiprocessing
import warnings
from copy import deepcopy
from module.genome import Genome, genome_score
warnings.filterwarnings(action='ignore')
np.random.seed(7777)

# %%
# !python --version
print('Pandas : %s'%(pd.__version__))
print('Numpy : %s'%(np.__version__))
# Out:
# Python 3.7.4
# Pandas : 0.25.1
# Numpy : 1.16.5

# %% [markdown]
# ## 2. 데이터 전처리
# ## Data Cleansing & Pre-Processing

# %%
# 입력하세요.

# %% [markdown]
# ## 3. 탐색적 자료분석
# ## Exploratory Data Analysis

# %%
# 입력하세요.

# %% [markdown]
# ## 4. 변수 선택 및 모델 구축
# ## Feature Engineering & Initial Modeling

# %%
CPU_CORE = multiprocessing.cpu_count() # 멀티프로세싱 CPU 사용 수
N_POPULATION = 100                      # 세대당 생성수
N_BEST = 10                             # 베스트 수
N_CHILDREN = 10                         # 자손 유전자 수
PROB_MUTATION = 0.5                    # 돌연변이
REVERSE = False                      # 배열 순서 (False: ascending order, True: descending order)

score_ini = 1e8                        # 초기 점수
input_length = 125                     # 입력 데이터 길이
output_length_1 = 17                    # Event (CHECK_1~4, PROCESS)
# output_length_2 = 12                   # MOL(0~5.5, step:0.5)
output_length_2 = 13
h1 = 100                                # 히든레이어1 노드 수
h2 = 100                                # 히든레이어2 노드 수
h3 = 100                                # 히든레이어3 노드 수
EPOCHS = 1000                          # 반복 횟수

genomes = []
for _ in range(N_POPULATION):
    genome = Genome(score_ini, input_length, output_length_1, output_length_2, h1, h2, h3)
    genomes.append(genome)
try:
    for i in range(N_BEST):
        genomes[i] = best_genomes[i]
except:
    best_genomes = []
    for _ in range(5):
        genome = Genome(score_ini, input_length, output_length_1, output_length_2, h1, h2, h3)
        best_genomes.append(genome)

# %%
n_gen = 1
score_history = []
high_score_history = []
mean_score_history = []
while n_gen <= EPOCHS:    
    genomes = np.array(genomes)    
    while len(genomes)%CPU_CORE != 0:
        genomes = np.append(genomes, Genome(score_ini, input_length, output_length_1, output_length_2, h1, h2, h3))
    genomes = genomes.reshape((len(genomes)//CPU_CORE, CPU_CORE))
    
    for idx, _genomes in enumerate(genomes):
        if __name__ == '__main__':
            pool = multiprocessing.Pool(processes=CPU_CORE)
            genomes[idx] = pool.map(genome_score, _genomes)
            pool.close()
            pool.join()    
    genomes = list(genomes.reshape(genomes.shape[0]*genomes.shape[1]))    
    
     # score에 따라 정렬
    genomes.sort(key=lambda x: x.score, reverse=REVERSE)
    
    # 평균 점수
    s = 0 
    for i in range(N_BEST):
        s += genomes[i].score
    s /= N_BEST
    
    # Best Score
    bs = genomes[0].score 
    
    # Best Model 추가
    if best_genomes is not None:
        genomes.extend(best_genomes)
        
    # score에 따라 정렬
#     genomes.sort(key=lambda x: x.score, reverse=REVERSE)
    genomes.sort(key=lambda x: x.score)
    
    score_history.append([n_gen, genomes[0].score])
    high_score_history.append([n_gen, bs])
    mean_score_history.append([n_gen, s])
    
    # 결과 출력
    print('EPOCH #%s\tHistory Best Score: %s\tBest Score: %s\tMean Score: %s' % (n_gen, -1 * genomes[0].score, -1 * bs, -1 * s))    
    
    # 모델 업데이트
    best_genomes = deepcopy(genomes[:N_BEST])
    
    # CHILDREN 생성
    for i in range(N_CHILDREN):
        new_genome = deepcopy(best_genomes[0])
        a_genome = np.random.choice(best_genomes)
        b_genome = np.random.choice(best_genomes)
        
        for j in range(input_length):
            cut = np.random.randint(new_genome.w1.shape[1])
            new_genome.w1[j, :cut] = a_genome.w1[j, :cut]
            new_genome.w1[j, cut:] = b_genome.w1[j, cut:]
        
        for j in range(h1):
            cut = np.random.randint(new_genome.w2.shape[1])
            new_genome.w2[j, :cut] = a_genome.w2[j, :cut]
            new_genome.w2[j, cut:] = b_genome.w2[j, cut:]
        
        for j in range(h2):
            cut = np.random.randint(new_genome.w3.shape[1])
            new_genome.w3[j, :cut] = a_genome.w3[j, :cut]
            new_genome.w3[j, cut:] = b_genome.w3[j, cut:]
        
        for j in range(h3):
            cut = np.random.randint(new_genome.w4.shape[1])
            new_genome.w4[j, :cut] = a_genome.w4[j, :cut]
            new_genome.w4[j, cut:] = b_genome.w4[j, cut:]
            
        for j in range(input_length):
            cut = np.random.randint(new_genome.w5.shape[1])
            new_genome.w5[j, :cut] = a_genome.w5[j, :cut]
            new_genome.w5[j, cut:] = b_genome.w5[j, cut:]
        
        for j in range(h1):
            cut = np.random.randint(new_genome.w6.shape[1])
            new_genome.w6[j, :cut] = a_genome.w6[j, :cut]
            new_genome.w6[j, cut:] = b_genome.w6[j, cut:]
        
        for j in range(h2):
            cut = np.random.randint(new_genome.w7.shape[1])
            new_genome.w7[j, :cut] = a_genome.w7[j, :cut]
            new_genome.w7[j, cut:] = b_genome.w7[j, cut:]
        
        for j in range(h3):
            cut = np.random.randint(new_genome.w8.shape[1])
            new_genome.w8[j, :cut] = a_genome.w8[j, :cut]
            new_genome.w8[j, cut:] = b_genome.w8[j, cut:]
        
        best_genomes.append(new_genome)
    
    # 모델 초기화
    genomes = []
    for i in range(int(N_POPULATION / len(best_genomes))):
        for bg in best_genomes:
            new_genome = deepcopy(bg)            
            mean = 0
            stddev = 0.2                        
            # 50% 확률로 모델 변형
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w1 += new_genome.w1 * np.random.normal(mean, stddev, size=(input_length, h1)) * np.random.randint(0, 2, (input_length, h1))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w2 += new_genome.w2 * np.random.normal(mean, stddev, size=(h1, h2)) * np.random.randint(0, 2, (h1, h2))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w3 += new_genome.w3 * np.random.normal(mean, stddev, size=(h2, h3)) * np.random.randint(0, 2, (h2, h3))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w4 += new_genome.w4 * np.random.normal(mean, stddev, size=(h3, output_length_1)) * np.random.randint(0, 2, (h3, output_length_1))                
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w5 += new_genome.w5 * np.random.normal(mean, stddev, size=(input_length, h1)) * np.random.randint(0, 2, (input_length, h1))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w6 += new_genome.w6 * np.random.normal(mean, stddev, size=(h1, h2)) * np.random.randint(0, 2, (h1, h2))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w7 += new_genome.w7 * np.random.normal(mean, stddev, size=(h2, h3)) * np.random.randint(0, 2, (h2, h3))
            if np.random.uniform(0, 1) < PROB_MUTATION:
                new_genome.w8 += new_genome.w8 * np.random.normal(mean, stddev, size=(h3, output_length_2)) * np.random.randint(0, 2, (h3, output_length_2))
            genomes.append(new_genome)
            
    if REVERSE:
        if bs < score_ini:
            genomes[len(genomes)//2:] = [Genome(score_ini, input_length, output_length_1, output_length_2, h1, h2, h3) for _ in range(N_POPULATION//2)]
    else:
        if bs > score_ini:
            genomes[len(genomes)//2:] = [Genome(score_ini, input_length, output_length_1, output_length_2, h1, h2, h3) for _ in range(N_POPULATION//2)]  
        
    n_gen += 1
# Out:
# EPOCH #1	History Best Score: 0.667077040018046	Best Score: 0.667077040018046	Mean Score: 0.5918375280891823
# EPOCH #2	History Best Score: 0.7710410724220725	Best Score: 0.7710410724220725	Mean Score: 0.718506409144596
# EPOCH #3	History Best Score: 0.8455928404897816	Best Score: 0.8455928404897816	Mean Score: 0.761175295846715
# EPOCH #4	History Best Score: 0.8455928404897816	Best Score: 0.8254744256905276	Mean Score: 0.7672849562914484
# EPOCH #5	History Best Score: 0.8455928404897816	Best Score: 0.8136112680207715	Mean Score: 0.7606278394991072
# EPOCH #6	History Best Score: 0.8455928404897816	Best Score: 0.8404491836306479	Mean Score: 0.7845699833174156
# EPOCH #7	History Best Score: 0.8455928404897816	Best Score: 0.8417028014339419	Mean Score: 0.7532034927457183
# EPOCH #8	History Best Score: 0.8455928404897816	Best Score: 0.7954946181388426	Mean Score: 0.7641000585907616
# EPOCH #9	History Best Score: 0.8455928404897816	Best Score: 0.7988215809228946	Mean Score: 0.7600729330605496
# EPOCH #10	History Best Score: 0.8455928404897816	Best Score: 0.78426273487471	Mean Score: 0.7479882692954996
# EPOCH #11	History Best Score: 0.8455928404897816	Best Score: 0.7819764003384421	Mean Score: 0.7479888622890414
# EPOCH #12	History Best Score: 0.8455928404897816	Best Score: 0.8308799253352371	Mean Score: 0.7729771983067782
# EPOCH #13	History Best Score: 0.8455928404897816	Best Score: 0.8214397482337624	Mean Score: 0.7818082910742363
# EPOCH #14	History Best Score: 0.8455928404897816	Best Score: 0.7819262848728764	Mean Score: 0.7680715281138082
# EPOCH #15	History Best Score: 0.8455928404897816	Best Score: 0.8004334169344492	Mean Score: 0.7334466385535064
# EPOCH #16	History Best Score: 0.8455928404897816	Best Score: 0.8367506450680368	Mean Score: 0.7503438584688092
# EPOCH #17	History Best Score: 0.8455928404897816	Best Score: 0.8238459019324545	Mean Score: 0.7810599064397261
# EPOCH #18	History Best Score: 0.8455928404897816	Best Score: 0.7958161944946337	Mean Score: 0.7660996683261203
# EPOCH #19	History Best Score: 0.8455928404897816	Best Score: 0.833039701291795	Mean Score: 0.7594911463601547
# EPOCH #20	History Best Score: 0.8455928404897816	Best Score: 0.8455928404897816	Mean Score: 0.7634733335500663
# EPOCH #21	History Best Score: 0.8455928404897816	Best Score: 0.8435678782998776	Mean Score: 0.7808298777702375
# EPOCH #22	History Best Score: 0.8455928404897816	Best Score: 0.7697737714039418	Mean Score: 0.7419340377579126
# EPOCH #23	History Best Score: 0.8455928404897816	Best Score: 0.8035874261885182	Mean Score: 0.7852253532032677
# EPOCH #24	History Best Score: 0.8455928404897816	Best Score: 0.7978120667965074	Mean Score: 0.7787758840421337
# EPOCH #25	History Best Score: 0.8455928404897816	Best Score: 0.7892817804720113	Mean Score: 0.7514576019128705
# EPOCH #26	History Best Score: 0.8455928404897816	Best Score: 0.8003714919536176	Mean Score: 0.7704429103739538
# EPOCH #27	History Best Score: 0.8455928404897816	Best Score: 0.8450906136648436	Mean Score: 0.7897656065031949
# EPOCH #28	History Best Score: 0.8455928404897816	Best Score: 0.8256180687251292	Mean Score: 0.7853986964781559
# EPOCH #29	History Best Score: 0.8455928404897816	Best Score: 0.7860235140226034	Mean Score: 0.7549479125709662
# EPOCH #30	History Best Score: 0.8455928404897816	Best Score: 0.8290926099273045	Mean Score: 0.7909557051261542
# EPOCH #31	History Best Score: 0.8455928404897816	Best Score: 0.8286941860293139	Mean Score: 0.7696684794593621
# EPOCH #32	History Best Score: 0.8455928404897816	Best Score: 0.8437103785064773	Mean Score: 0.7528480151869188
# EPOCH #33	History Best Score: 0.8455928404897816	Best Score: 0.8410716562373372	Mean Score: 0.7799103996356073
# EPOCH #34	History Best Score: 0.8455928404897816	Best Score: 0.7721339227983359	Mean Score: 0.7405504460894352
# EPOCH #35	History Best Score: 0.8455928404897816	Best Score: 0.8217009388525137	Mean Score: 0.775505519466978
# EPOCH #36	History Best Score: 0.8455928404897816	Best Score: 0.7936117106983872	Mean Score: 0.7568140302501597
# EPOCH #37	History Best Score: 0.8455928404897816	Best Score: 0.8009029008301346	Mean Score: 0.7618671163208763
# EPOCH #38	History Best Score: 0.8455928404897816	Best Score: 0.8317980063795608	Mean Score: 0.7941582643235694
# EPOCH #39	History Best Score: 0.8455928404897816	Best Score: 0.8057147298548147	Mean Score: 0.7580134832839611
# EPOCH #40	History Best Score: 0.8455928404897816	Best Score: 0.8455928404897816	Mean Score: 0.7908312621477591
# EPOCH #41	History Best Score: 0.8455928404897816	Best Score: 0.8326132728412762	Mean Score: 0.7928981075115646
# EPOCH #42	History Best Score: 0.8455928404897816	Best Score: 0.8434873642238924	Mean Score: 0.8047538889592086
# EPOCH #43	History Best Score: 0.8455928404897816	Best Score: 0.8455928404897816	Mean Score: 0.8075835136624567
# EPOCH #44	History Best Score: 0.8455928404897816	Best Score: 0.8450319853595131	Mean Score: 0.8177140249136283
# EPOCH #45	History Best Score: 0.8455928404897816	Best Score: 0.8455928404897816	Mean Score: 0.8005007213913269
# EPOCH #46	History Best Score: 0.8455928404897816	Best Score: 0.837753854510008	Mean Score: 0.7974738062971449
# EPOCH #47	History Best Score: 0.8506090013680142	Best Score: 0.8506090013680142	Mean Score: 0.8124028937490708
# EPOCH #48	History Best Score: 0.8506090013680142	Best Score: 0.8395344880606731	Mean Score: 0.8034285657412139
# EPOCH #49	History Best Score: 0.8506090013680142	Best Score: 0.8246814966008548	Mean Score: 0.7631408497915121
# EPOCH #50	History Best Score: 0.8506090013680142	Best Score: 0.7612534611252616	Mean Score: 0.7344075268712611
# EPOCH #51	History Best Score: 0.8506090013680142	Best Score: 0.8017151996255878	Mean Score: 0.76743227991968
# EPOCH #52	History Best Score: 0.8506090013680142	Best Score: 0.8209657717308152	Mean Score: 0.7752208884532543
# EPOCH #53	History Best Score: 0.8506090013680142	Best Score: 0.8164291663223334	Mean Score: 0.7693145424619011
# EPOCH #54	History Best Score: 0.8506090013680142	Best Score: 0.7973483256801747	Mean Score: 0.7505522804653693
# EPOCH #55	History Best Score: 0.8506090013680142	Best Score: 0.8425649668533798	Mean Score: 0.7585284790738313
# EPOCH #56	History Best Score: 0.8506090013680142	Best Score: 0.8378254133611954	Mean Score: 0.7659047988161587
# EPOCH #57	History Best Score: 0.8506090013680142	Best Score: 0.7886703894010866	Mean Score: 0.7480008514976262
# EPOCH #58	History Best Score: 0.8506090013680142	Best Score: 0.7909784837511595	Mean Score: 0.7389643539891139
# EPOCH #59	History Best Score: 0.8506090013680142	Best Score: 0.7983027089431188	Mean Score: 0.7578290861739344
# EPOCH #60	History Best Score: 0.8506090013680142	Best Score: 0.7847282810124526	Mean Score: 0.7601924415729236
# EPOCH #61	History Best Score: 0.8506090013680142	Best Score: 0.8304491744142929	Mean Score: 0.7492798474648035
# EPOCH #62	History Best Score: 0.8506090013680142	Best Score: 0.7967915196018043	Mean Score: 0.7668875074176886
# EPOCH #63	History Best Score: 0.8506090013680142	Best Score: 0.8146609226247074	Mean Score: 0.7874999348120133
# EPOCH #64	History Best Score: 0.8506090013680142	Best Score: 0.8070411744163996	Mean Score: 0.7610738261664356
# EPOCH #65	History Best Score: 0.8506090013680142	Best Score: 0.8024299494491713	Mean Score: 0.7742928720083165
# EPOCH #66	History Best Score: 0.8506090013680142	Best Score: 0.8037639961868867	Mean Score: 0.7701053368457345
# EPOCH #67	History Best Score: 0.8506090013680142	Best Score: 0.8098695078260238	Mean Score: 0.7700475143231096
# EPOCH #68	History Best Score: 0.8506090013680142	Best Score: 0.8506090013680142	Mean Score: 0.7700978317911431
# EPOCH #69	History Best Score: 0.8506090013680142	Best Score: 0.7834301669405167	Mean Score: 0.7550710305815593
# EPOCH #70	History Best Score: 0.8506090013680142	Best Score: 0.7601323099902522	Mean Score: 0.734336738507902
# EPOCH #71	History Best Score: 0.8506090013680142	Best Score: 0.8422249755228975	Mean Score: 0.7756722014440388
# EPOCH #72	History Best Score: 0.8506090013680142	Best Score: 0.7947211975854379	Mean Score: 0.7713070824391621
# EPOCH #73	History Best Score: 0.8506090013680142	Best Score: 0.8312492185299115	Mean Score: 0.767617921954397
# EPOCH #74	History Best Score: 0.8506090013680142	Best Score: 0.8434358048627332	Mean Score: 0.7631132045189972
# EPOCH #75	History Best Score: 0.8506090013680142	Best Score: 0.8148509015416372	Mean Score: 0.782304119896473
# EPOCH #76	History Best Score: 0.8506090013680142	Best Score: 0.7970972322364746	Mean Score: 0.7703132458704408
# EPOCH #77	History Best Score: 0.8506090013680142	Best Score: 0.8457534354730739	Mean Score: 0.8034646705108859
# EPOCH #78	History Best Score: 0.8506090013680142	Best Score: 0.8102887997457691	Mean Score: 0.7712723927610409
# EPOCH #79	History Best Score: 0.8506090013680142	Best Score: 0.8506090013680142	Mean Score: 0.7733433703094953
# EPOCH #80	History Best Score: 0.8506090013680142	Best Score: 0.8470142082398514	Mean Score: 0.7980420092188071
# EPOCH #81	History Best Score: 0.8565967933843776	Best Score: 0.8565967933843776	Mean Score: 0.7825024905314882
# EPOCH #82	History Best Score: 0.8565967933843776	Best Score: 0.8265645146375683	Mean Score: 0.7962955121946471
# EPOCH #83	History Best Score: 0.8565967933843776	Best Score: 0.831676261404087	Mean Score: 0.7905764975879782
# EPOCH #84	History Best Score: 0.8565967933843776	Best Score: 0.7973707942755552	Mean Score: 0.7697687583944718
# EPOCH #85	History Best Score: 0.8565967933843776	Best Score: 0.8101295389395601	Mean Score: 0.7732616068343522
# EPOCH #86	History Best Score: 0.8565967933843776	Best Score: 0.810059435394691	Mean Score: 0.7745106125868757
# EPOCH #87	History Best Score: 0.8565967933843776	Best Score: 0.8524616638039645	Mean Score: 0.7876988504298803
# EPOCH #88	History Best Score: 0.8565967933843776	Best Score: 0.8117949066122124	Mean Score: 0.7820134254123479
# EPOCH #89	History Best Score: 0.8565967933843776	Best Score: 0.8361572654214963	Mean Score: 0.7905022327079403
# EPOCH #90	History Best Score: 0.8565967933843776	Best Score: 0.8472194134527445	Mean Score: 0.7837324274300839
# EPOCH #91	History Best Score: 0.8565967933843776	Best Score: 0.8122888685612186	Mean Score: 0.7901985191387373
# EPOCH #92	History Best Score: 0.8565967933843776	Best Score: 0.8322658838499662	Mean Score: 0.781189096092539
# EPOCH #93	History Best Score: 0.8565967933843776	Best Score: 0.821382149088057	Mean Score: 0.7836021727308511
# EPOCH #94	History Best Score: 0.8565967933843776	Best Score: 0.8107773436484532	Mean Score: 0.7884013200408059
# EPOCH #95	History Best Score: 0.8565967933843776	Best Score: 0.8404261243108085	Mean Score: 0.7953306135172469
# EPOCH #96	History Best Score: 0.8565967933843776	Best Score: 0.8027868988725808	Mean Score: 0.7715108567225373
# EPOCH #97	History Best Score: 0.8565967933843776	Best Score: 0.812351045163167	Mean Score: 0.7804183059821396
# EPOCH #98	History Best Score: 0.8565967933843776	Best Score: 0.8307241035460101	Mean Score: 0.8035606868141967
# EPOCH #99	History Best Score: 0.8573603284463099	Best Score: 0.8573603284463099	Mean Score: 0.7949529185359451
# EPOCH #100	History Best Score: 0.8573603284463099	Best Score: 0.7911920053007792	Mean Score: 0.7795896017487082
# EPOCH #101	History Best Score: 0.8573603284463099	Best Score: 0.8192495881496284	Mean Score: 0.7779171234864355
# EPOCH #102	History Best Score: 0.8573603284463099	Best Score: 0.7979086392398772	Mean Score: 0.7607093508904672
# EPOCH #103	History Best Score: 0.8573603284463099	Best Score: 0.8151647491455232	Mean Score: 0.7821947422543343
# EPOCH #104	History Best Score: 0.8573603284463099	Best Score: 0.808662380681303	Mean Score: 0.7757226447385458
# EPOCH #105	History Best Score: 0.8573603284463099	Best Score: 0.8208945385241658	Mean Score: 0.7723952482853307
# EPOCH #106	History Best Score: 0.8573603284463099	Best Score: 0.810759645760185	Mean Score: 0.7827922409419292
# EPOCH #107	History Best Score: 0.8573603284463099	Best Score: 0.8085971255242516	Mean Score: 0.777502004611758
# EPOCH #108	History Best Score: 0.8573603284463099	Best Score: 0.7806629591758051	Mean Score: 0.7680643880103105
# EPOCH #109	History Best Score: 0.8573603284463099	Best Score: 0.8098505590004486	Mean Score: 0.7719829282188023
# EPOCH #110	History Best Score: 0.8573603284463099	Best Score: 0.8542495383374248	Mean Score: 0.8070772799546637
# EPOCH #111	History Best Score: 0.8573603284463099	Best Score: 0.7876528949016778	Mean Score: 0.7676900412093126
# EPOCH #112	History Best Score: 0.8573603284463099	Best Score: 0.8549933872653938	Mean Score: 0.7870873344227695
# EPOCH #113	History Best Score: 0.8573603284463099	Best Score: 0.8065283060663088	Mean Score: 0.7770085698708838
# EPOCH #114	History Best Score: 0.8573603284463099	Best Score: 0.8139220868086122	Mean Score: 0.7657378041277193
# EPOCH #115	History Best Score: 0.8573603284463099	Best Score: 0.8011370708519568	Mean Score: 0.7652742874899257
# EPOCH #116	History Best Score: 0.8573603284463099	Best Score: 0.8313434772630989	Mean Score: 0.7885650450708617
# EPOCH #117	History Best Score: 0.8573603284463099	Best Score: 0.8185807327010884	Mean Score: 0.782460014329321
# EPOCH #118	History Best Score: 0.8573603284463099	Best Score: 0.8248645356025813	Mean Score: 0.7974718662784018
# EPOCH #119	History Best Score: 0.8573603284463099	Best Score: 0.8260133981222598	Mean Score: 0.7746466778375799
# EPOCH #120	History Best Score: 0.8573603284463099	Best Score: 0.8178859955337544	Mean Score: 0.7680918893914603
# EPOCH #121	History Best Score: 0.8573603284463099	Best Score: 0.8088537917905188	Mean Score: 0.7853501006092936
# EPOCH #122	History Best Score: 0.8573603284463099	Best Score: 0.8491799563943531	Mean Score: 0.7816960632545058
# EPOCH #123	History Best Score: 0.8573603284463099	Best Score: 0.829597502473165	Mean Score: 0.7840212448658528
# EPOCH #124	History Best Score: 0.8573603284463099	Best Score: 0.8294564746889711	Mean Score: 0.7883860805836049
# EPOCH #125	History Best Score: 0.8573603284463099	Best Score: 0.8106027281024785	Mean Score: 0.7805967419697211
# EPOCH #126	History Best Score: 0.8573603284463099	Best Score: 0.7870866049015822	Mean Score: 0.7627658607938873
# EPOCH #127	History Best Score: 0.8573603284463099	Best Score: 0.7928391951370136	Mean Score: 0.7719436769781889
# EPOCH #128	History Best Score: 0.8573603284463099	Best Score: 0.8255915532722208	Mean Score: 0.7798012466941907
# EPOCH #129	History Best Score: 0.8573603284463099	Best Score: 0.8340817638137031	Mean Score: 0.7781308518593855
# EPOCH #130	History Best Score: 0.8573603284463099	Best Score: 0.8165197938117091	Mean Score: 0.7844133524413881
# EPOCH #131	History Best Score: 0.8573603284463099	Best Score: 0.8071460073807203	Mean Score: 0.772701125179301
# EPOCH #132	History Best Score: 0.8573603284463099	Best Score: 0.8378065935645881	Mean Score: 0.7892829871997518
# EPOCH #133	History Best Score: 0.8573603284463099	Best Score: 0.8013154503279948	Mean Score: 0.7810435828309379
# EPOCH #134	History Best Score: 0.8573603284463099	Best Score: 0.8257027363050343	Mean Score: 0.7851450296646885
# EPOCH #135	History Best Score: 0.8573603284463099	Best Score: 0.8224666707716018	Mean Score: 0.7660840221330381
# EPOCH #136	History Best Score: 0.8573603284463099	Best Score: 0.8036345358395395	Mean Score: 0.7568975477251136
# EPOCH #137	History Best Score: 0.8573603284463099	Best Score: 0.8430291055558338	Mean Score: 0.7780189229500118
# EPOCH #138	History Best Score: 0.8573603284463099	Best Score: 0.784464469876805	Mean Score: 0.7574218985883168
# EPOCH #139	History Best Score: 0.8573603284463099	Best Score: 0.8127659470258844	Mean Score: 0.7844500154094863
# EPOCH #140	History Best Score: 0.8573603284463099	Best Score: 0.8573603284463099	Mean Score: 0.7783856928075241
# EPOCH #141	History Best Score: 0.8573603284463099	Best Score: 0.8333943712034378	Mean Score: 0.7922326444506443
# EPOCH #142	History Best Score: 0.8573603284463099	Best Score: 0.8397804071794351	Mean Score: 0.795441215406399
# EPOCH #143	History Best Score: 0.8573603284463099	Best Score: 0.8100401919383432	Mean Score: 0.7797175752023805
# EPOCH #144	History Best Score: 0.8573603284463099	Best Score: 0.8240125422593642	Mean Score: 0.7906905124521624
# EPOCH #145	History Best Score: 0.8573603284463099	Best Score: 0.8090348747306465	Mean Score: 0.7892725805792764
# EPOCH #146	History Best Score: 0.8573603284463099	Best Score: 0.8278404289976192	Mean Score: 0.7859051238551149
# EPOCH #147	History Best Score: 0.8573603284463099	Best Score: 0.8307784901337386	Mean Score: 0.798852185053526
# EPOCH #148	History Best Score: 0.8573603284463099	Best Score: 0.8541479956117862	Mean Score: 0.7873549364612284
# EPOCH #149	History Best Score: 0.8573603284463099	Best Score: 0.8278194012257137	Mean Score: 0.801954684517821
# EPOCH #150	History Best Score: 0.8573968344278778	Best Score: 0.8573968344278778	Mean Score: 0.8081138916957121
# EPOCH #151	History Best Score: 0.8573968344278778	Best Score: 0.8511588521705898	Mean Score: 0.801760774531678
# EPOCH #152	History Best Score: 0.8573968344278778	Best Score: 0.8082814662483261	Mean Score: 0.7758340159629191
# EPOCH #153	History Best Score: 0.8573968344278778	Best Score: 0.8330860288355165	Mean Score: 0.7972368409708114
# EPOCH #154	History Best Score: 0.8573968344278778	Best Score: 0.8234177100860408	Mean Score: 0.7985295411027107
# EPOCH #155	History Best Score: 0.8573968344278778	Best Score: 0.7984001505162409	Mean Score: 0.7782500135407913
# EPOCH #156	History Best Score: 0.8573968344278778	Best Score: 0.8084596789522286	Mean Score: 0.7922108166618416
# EPOCH #157	History Best Score: 0.8573968344278778	Best Score: 0.8183771135789778	Mean Score: 0.7930475764843928
# EPOCH #158	History Best Score: 0.8573968344278778	Best Score: 0.829645339304712	Mean Score: 0.7894575079627589
# EPOCH #159	History Best Score: 0.8573968344278778	Best Score: 0.80970041229144	Mean Score: 0.786564054112087
# EPOCH #160	History Best Score: 0.8573968344278778	Best Score: 0.8196266540961438	Mean Score: 0.7903889232054897
# EPOCH #161	History Best Score: 0.8573968344278778	Best Score: 0.8048559060223218	Mean Score: 0.7865923665676032
# EPOCH #162	History Best Score: 0.8573968344278778	Best Score: 0.8261787518167739	Mean Score: 0.7974232485862465
# EPOCH #163	History Best Score: 0.8573968344278778	Best Score: 0.8117202133226271	Mean Score: 0.8019885396709256
# EPOCH #164	History Best Score: 0.8573968344278778	Best Score: 0.8181432968507584	Mean Score: 0.7787336548839725
# EPOCH #165	History Best Score: 0.8573968344278778	Best Score: 0.8309291867519201	Mean Score: 0.7910643542821171
# EPOCH #166	History Best Score: 0.8573968344278778	Best Score: 0.8206771839612078	Mean Score: 0.7911344426552473
# EPOCH #167	History Best Score: 0.8573968344278778	Best Score: 0.82279491797905	Mean Score: 0.8050073353440899
# EPOCH #168	History Best Score: 0.8573968344278778	Best Score: 0.8432093958894443	Mean Score: 0.8119937077345943
# EPOCH #169	History Best Score: 0.8598562279364305	Best Score: 0.8598562279364305	Mean Score: 0.7923691384970409
# EPOCH #170	History Best Score: 0.8598562279364305	Best Score: 0.856641646311323	Mean Score: 0.8026550218968381
# EPOCH #171	History Best Score: 0.8598562279364305	Best Score: 0.7900011981261307	Mean Score: 0.7739155681536498
# EPOCH #172	History Best Score: 0.8598562279364305	Best Score: 0.8442955740299095	Mean Score: 0.7870136486537471
# EPOCH #173	History Best Score: 0.8598562279364305	Best Score: 0.8377445736406722	Mean Score: 0.7871099702187503
# EPOCH #174	History Best Score: 0.8598562279364305	Best Score: 0.8265456355929656	Mean Score: 0.7929191732330129
# EPOCH #175	History Best Score: 0.8598562279364305	Best Score: 0.8202896970968906	Mean Score: 0.7868204929337315
# EPOCH #176	History Best Score: 0.8598562279364305	Best Score: 0.811623740469905	Mean Score: 0.7876447461473157
# EPOCH #177	History Best Score: 0.8598562279364305	Best Score: 0.8237388868864042	Mean Score: 0.7759995876671082
# EPOCH #178	History Best Score: 0.8598562279364305	Best Score: 0.8137271584165443	Mean Score: 0.7886330138738809
# EPOCH #179	History Best Score: 0.8598562279364305	Best Score: 0.8352796318864987	Mean Score: 0.773296712863032
# EPOCH #180	History Best Score: 0.8598562279364305	Best Score: 0.8203686050401787	Mean Score: 0.7745956305726565
# EPOCH #181	History Best Score: 0.8598562279364305	Best Score: 0.8598562279364305	Mean Score: 0.7878466590742518
# EPOCH #182	History Best Score: 0.8598562279364305	Best Score: 0.8598562279364305	Mean Score: 0.788257987390465
# EPOCH #183	History Best Score: 0.8598562279364305	Best Score: 0.8488462352572884	Mean Score: 0.8022839630395568
# EPOCH #184	History Best Score: 0.8598562279364305	Best Score: 0.8095737952289505	Mean Score: 0.7817603622954026
# EPOCH #185	History Best Score: 0.8598562279364305	Best Score: 0.847767758917361	Mean Score: 0.8072941918726404
# EPOCH #186	History Best Score: 0.8598562279364305	Best Score: 0.8373453948793318	Mean Score: 0.8005205233337003
# EPOCH #187	History Best Score: 0.8598562279364305	Best Score: 0.8498077714147382	Mean Score: 0.8040875378249721
# EPOCH #188	History Best Score: 0.8623714971323312	Best Score: 0.8623714971323312	Mean Score: 0.7979006734654457
# EPOCH #189	History Best Score: 0.8623714971323312	Best Score: 0.8594064053051796	Mean Score: 0.7978445652299968
# EPOCH #190	History Best Score: 0.8623714971323312	Best Score: 0.816109741946014	Mean Score: 0.7873950335204702
# EPOCH #191	History Best Score: 0.8623714971323312	Best Score: 0.8294288870667813	Mean Score: 0.791283896362533
# EPOCH #192	History Best Score: 0.8623714971323312	Best Score: 0.8086108056669699	Mean Score: 0.7880170233129856
# EPOCH #193	History Best Score: 0.8623714971323312	Best Score: 0.811184421411067	Mean Score: 0.7933979835272771
# EPOCH #194	History Best Score: 0.8623714971323312	Best Score: 0.8578178590223352	Mean Score: 0.8068315087678014
# EPOCH #195	History Best Score: 0.8623714971323312	Best Score: 0.8110446663953502	Mean Score: 0.7872431767959929
# EPOCH #196	History Best Score: 0.8623714971323312	Best Score: 0.8294692999050585	Mean Score: 0.7943166560509868
# EPOCH #197	History Best Score: 0.8623714971323312	Best Score: 0.8397800332587525	Mean Score: 0.7923263836199856
# EPOCH #198	History Best Score: 0.8623714971323312	Best Score: 0.8206769259032719	Mean Score: 0.7947332256575649
# EPOCH #199	History Best Score: 0.8623714971323312	Best Score: 0.8313065381128529	Mean Score: 0.7949370453869096
# EPOCH #200	History Best Score: 0.8623714971323312	Best Score: 0.8076985032771383	Mean Score: 0.7930717774811941
# EPOCH #201	History Best Score: 0.8623714971323312	Best Score: 0.859558874535611	Mean Score: 0.7931676825571039
# EPOCH #202	History Best Score: 0.8623714971323312	Best Score: 0.8017603444037701	Mean Score: 0.7838862483729876
# EPOCH #203	History Best Score: 0.8623714971323312	Best Score: 0.8268315769521085	Mean Score: 0.8097441310834658
# EPOCH #204	History Best Score: 0.8623714971323312	Best Score: 0.78835025931531	Mean Score: 0.7760456150635874
# EPOCH #205	History Best Score: 0.8623714971323312	Best Score: 0.831993777117204	Mean Score: 0.7917283807008422
# EPOCH #206	History Best Score: 0.8623714971323312	Best Score: 0.8075516876220975	Mean Score: 0.7927046077279256
# EPOCH #207	History Best Score: 0.8623714971323312	Best Score: 0.8144439321809115	Mean Score: 0.7972655804325497
# EPOCH #208	History Best Score: 0.8623714971323312	Best Score: 0.8171611099142041	Mean Score: 0.7927798741815419
# EPOCH #209	History Best Score: 0.8623714971323312	Best Score: 0.8093328680098172	Mean Score: 0.7928349261921805
# EPOCH #210	History Best Score: 0.8623714971323312	Best Score: 0.8031659156142065	Mean Score: 0.7757439395768394
# EPOCH #211	History Best Score: 0.8623714971323312	Best Score: 0.8107011341953493	Mean Score: 0.7855324139889395
# EPOCH #212	History Best Score: 0.8623714971323312	Best Score: 0.8311199429147759	Mean Score: 0.8030541937172169
# EPOCH #213	History Best Score: 0.8623714971323312	Best Score: 0.8468299149361168	Mean Score: 0.7935395225365495
# EPOCH #214	History Best Score: 0.8623714971323312	Best Score: 0.8127120015065669	Mean Score: 0.7941736215330869
# EPOCH #215	History Best Score: 0.8623714971323312	Best Score: 0.8308355117212064	Mean Score: 0.8068221572702896
# EPOCH #216	History Best Score: 0.8623714971323312	Best Score: 0.8541887349723495	Mean Score: 0.7998841320160617
# EPOCH #217	History Best Score: 0.8623714971323312	Best Score: 0.8176738344599012	Mean Score: 0.7882487115201134
# EPOCH #218	History Best Score: 0.8623714971323312	Best Score: 0.8229966394098093	Mean Score: 0.7868061104755151
# EPOCH #219	History Best Score: 0.8623714971323312	Best Score: 0.8506639124102212	Mean Score: 0.802521052870276
# EPOCH #220	History Best Score: 0.8623714971323312	Best Score: 0.8325412439559913	Mean Score: 0.7878549739663914
# EPOCH #221	History Best Score: 0.8623714971323312	Best Score: 0.8274935201345096	Mean Score: 0.8073214276503157
# EPOCH #222	History Best Score: 0.8623714971323312	Best Score: 0.8207453481216916	Mean Score: 0.7988494263710437
# EPOCH #223	History Best Score: 0.8623714971323312	Best Score: 0.8268702048896625	Mean Score: 0.8021987924000417
# EPOCH #224	History Best Score: 0.8623714971323312	Best Score: 0.8031497814341447	Mean Score: 0.7813597339801689
# EPOCH #225	History Best Score: 0.8623714971323312	Best Score: 0.8379860535485139	Mean Score: 0.7930512289621523
# EPOCH #226	History Best Score: 0.8623714971323312	Best Score: 0.8084521706951426	Mean Score: 0.799409347681044
# EPOCH #227	History Best Score: 0.8623714971323312	Best Score: 0.8173743342335663	Mean Score: 0.8022160952172745
# EPOCH #228	History Best Score: 0.8623714971323312	Best Score: 0.8130618626753472	Mean Score: 0.782578548193173
# EPOCH #229	History Best Score: 0.8623714971323312	Best Score: 0.8098270722510534	Mean Score: 0.7877654181927934
# EPOCH #230	History Best Score: 0.8623714971323312	Best Score: 0.8142745294344992	Mean Score: 0.7911452439209051
# EPOCH #231	History Best Score: 0.8623714971323312	Best Score: 0.8230610672892943	Mean Score: 0.795235922975891
# EPOCH #232	History Best Score: 0.8623714971323312	Best Score: 0.8044419380835626	Mean Score: 0.7914022233689739
# EPOCH #233	History Best Score: 0.8623714971323312	Best Score: 0.8156433153931867	Mean Score: 0.7908730118177448
# EPOCH #234	History Best Score: 0.8623714971323312	Best Score: 0.842611441858779	Mean Score: 0.8023701070244087
# EPOCH #235	History Best Score: 0.8623714971323312	Best Score: 0.8301929935427145	Mean Score: 0.7968041746042523
# EPOCH #236	History Best Score: 0.8623714971323312	Best Score: 0.8623714971323312	Mean Score: 0.8098018295790006
# EPOCH #237	History Best Score: 0.8623714971323312	Best Score: 0.8309218988096024	Mean Score: 0.7945186507496416
# EPOCH #238	History Best Score: 0.8623714971323312	Best Score: 0.8443313150540247	Mean Score: 0.8042366114363123
# EPOCH #239	History Best Score: 0.8623714971323312	Best Score: 0.8623714971323312	Mean Score: 0.8095901867924005
# EPOCH #240	History Best Score: 0.8623714971323312	Best Score: 0.8567516342901241	Mean Score: 0.8050923021696968
# EPOCH #241	History Best Score: 0.8623714971323312	Best Score: 0.8516145179708167	Mean Score: 0.8121510975071111
# EPOCH #242	History Best Score: 0.8623714971323312	Best Score: 0.8451869092124532	Mean Score: 0.7954918715929156
# EPOCH #243	History Best Score: 0.8623714971323312	Best Score: 0.8515243973809578	Mean Score: 0.7970291923233215
# EPOCH #244	History Best Score: 0.8623714971323312	Best Score: 0.8216365634916222	Mean Score: 0.7946077421121956
# EPOCH #245	History Best Score: 0.8623714971323312	Best Score: 0.8614008244951051	Mean Score: 0.7984846194985691
# EPOCH #246	History Best Score: 0.8623714971323312	Best Score: 0.8607203933048712	Mean Score: 0.8129589116828099
# EPOCH #247	History Best Score: 0.8623714971323312	Best Score: 0.8587993240110928	Mean Score: 0.8214876653567525
# EPOCH #248	History Best Score: 0.8623714971323312	Best Score: 0.8580392235774018	Mean Score: 0.816617092487926
# EPOCH #249	History Best Score: 0.8623714971323312	Best Score: 0.8502292199615186	Mean Score: 0.8134458164573465
# EPOCH #250	History Best Score: 0.8648176344504886	Best Score: 0.8648176344504886	Mean Score: 0.824731463423159
# EPOCH #251	History Best Score: 0.8648176344504886	Best Score: 0.8045399763999873	Mean Score: 0.7902066613046836
# EPOCH #252	History Best Score: 0.8648176344504886	Best Score: 0.8118818247719569	Mean Score: 0.7783843471332271
# EPOCH #253	History Best Score: 0.8648176344504886	Best Score: 0.7851594124709494	Mean Score: 0.7763615456059095
# EPOCH #254	History Best Score: 0.8648176344504886	Best Score: 0.8611027184253058	Mean Score: 0.7866327810870517
# EPOCH #255	History Best Score: 0.8648176344504886	Best Score: 0.7924087613419498	Mean Score: 0.7661167072615751
# EPOCH #256	History Best Score: 0.8648176344504886	Best Score: 0.8306882212044538	Mean Score: 0.7890784161657951
# EPOCH #257	History Best Score: 0.8648176344504886	Best Score: 0.8536771842684195	Mean Score: 0.8008020432981191

# %% [markdown]
# ## 6. 결과 및 결언
# ## Conclusion & Discussion

# %% [markdown]
# ### 결과 그래프

# %%
import matplotlib.pyplot as plt

# Score Graph
score_history = np.array(score_history)
high_score_history = np.array(high_score_history)
mean_score_history = np.array(mean_score_history)

plt.plot(score_history[:,0], score_history[:,1], '-o', label='BEST')
plt.plot(high_score_history[:,0], high_score_history[:,1], '-o', label='High')
plt.plot(mean_score_history[:,0], mean_score_history[:,1], '-o', label='Mean')
plt.legend()
plt.xlim(0, EPOCHS)
plt.ylim(bottom=0)
plt.xlabel('Epochs')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# ### Submission 파일 만들기

# %%
# 재고 계산
from module.simulator import Simulator
simulator = Simulator()
order = pd.read_csv('module/order.csv')
submission,_ = best_genomes[0].predict(order)
_, df_stock = simulator.get_score(submission) 

# PRT 개수 계산
PRTs = df_stock[['PRT_1', 'PRT_2', 'PRT_3', 'PRT_4']].values
PRTs = (PRTs[:-1] - PRTs[1:])[24*23:]
PRTs = np.ceil(PRTs * 1.1)
PAD = np.zeros((24*23+1, 4))
PRTs = np.append(PRTs, PAD, axis=0).astype(int)

# Submission 파일에 PRT 입력
submission.loc[:, 'PRT_1':'PRT_4'] = PRTs
submission.to_csv('Dacon_baseline.csv', index=False)

# %% [markdown]
# ### 점수 향상 팁
# 해당 코드는 단순한 모델로 다음 방법으로 점수 향상을 꾀할 수 있습니다.
# 1. 성형 공정 2개 라인을 따로 모델링
# 2. CHANGE, STOP 이벤트 활용
# 3. 수요 초과분 외 다양한 양상을 반영하는 목적함수
# 4. 유전 알고리즘 외 효율적인 학습 기법
